# %%
import numpy as numpy

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/vega/vega-datasets/master/data/weather.json'
df=pd.read_json(url)

# %%
df.head()
# Out:
#   day                   record                   normal  \
# 0   M  {'high': 62, 'low': 15}  {'high': 50, 'low': 38}
# 1   T  {'high': 62, 'low': 23}  {'high': 50, 'low': 38}
# 2   W  {'high': 61, 'low': 20}  {'high': 50, 'low': 38}
# 3   T  {'high': 67, 'low': 21}  {'high': 50, 'low': 38}
# 4   F  {'high': 61, 'low': 23}  {'high': 50, 'low': 38}
#
#                     actual  id forecast
# 0  {'high': 48, 'low': 36}   0      NaN
# 1  {'high': 50, 'low': 40}   1      NaN
# 2  {'high': 55, 'low': 36}   2      NaN
# 3  {'high': 51, 'low': 33}   3      NaN
# 4  {'high': 50, 'low': 30}   4      NaN

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            891
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

# %%
dataframe=pd.read_csv('https://raw.githubusercontent.com/sushantag9/Supermarket-Sales-Data-Analysis/master/supermarket_sales%20-%20Sheet1.csv',parse_dates=['Date'])

# %%
dataframe.replace('Male',"M")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal       M
# 3    123-19-1176      A     Yangon        Member       M
# 4    373-73-7910      A     Yangon        Normal       M
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal       M
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member       M
# 998  347-56-2442      A     Yangon        Normal       M
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
dataframe
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...
